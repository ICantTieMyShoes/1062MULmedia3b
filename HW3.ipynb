# %%
#title

# %%
title#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fac2d0e296c4> in <module>()
# ----> 1 title#
#
# NameError: name 'title' is not defined

# %%
Markdown
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a36b6f0ee89b> in <module>()
# ----> 1 Markdown
#
# NameError: name 'Markdown' is not defined

# %%
Markdown title#
# Out:
#   File "<ipython-input-4-d838bda1e8cf>", line 1
#     Markdown title#
#                  ^
# SyntaxError: invalid syntax

# %%
Markdown title papap#
# Out:
#   File "<ipython-input-5-5f73c77da40b>", line 1
#     Markdown title papap#
#                  ^
# SyntaxError: invalid syntax

# %%
# Homework3

# %%
## paapa

# %% [markdown]
# # Homework3

# %%
from skimage import io
img1=io.imread('Lena1.bmp',as_grey = True)
print(type(img1))
print(img1.shape)
io.imshow(img1)
io.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7d8bd198d75b> in <module>()
#       1 from skimage import io
# ----> 2 img1=io.imread('Lena1.bmp',as_grey = True)
#       3 print(type(img1))
#       4 print(img1.shape)
#       5 io.imshow(img1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\_io.py in imread(fname, as_grey, plugin, flatten, **plugin_args)
#      59
#      60     with file_or_url_context(fname) as fname:
# ---> 61         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      62
#      63     if not hasattr(img, 'ndim'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     209                                (plugin, kind))
#     210
# --> 211     return func(*args, **kwargs)
#     212
#     213
#
# ...

# %%
from skimage import io
img1=io.imread('blodbrother.jpg',as_grey = True)
print(type(img1))
print(img1.shape)
io.imshow(img1)
io.show()
# Out:
# <class 'numpy.ndarray'>
# (225, 225)
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
